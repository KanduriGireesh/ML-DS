# %% [markdown]
# # Sales Data Analysis

# %% [markdown]
# ### About the DataSet

# %% [markdown]
# The dataset consists of 11 columns, each column representing an attribute of purchase on a product -</br>
# <b>Order ID</b>- A unique ID for each order placed on a product</br>
# <b>Product </b>- Item that is purchased</br>
# <b>Quantity Ordered </b>- Describes how many of that products are ordered</br>
# <b>Price Each </b>- Price of a unit of that product</br>
# <b>Order Date </b>- Date on which the order is placed</br>
# <b>Purchase Address </b>- Address to where the order is shipped</br>
# <b>Month, Sales, City, Hour</b> - Extra attributes formed from the above.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\giree\Downloads\Sales Data.csv.zip")
df
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# 0          1700.00  2019-12-30 00:01:00
# ...

# %%
df1=df.copy()

# %%
df
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# 0          1700.00  2019-12-30 00:01:00
# ...

# %% [markdown]
# ### Data Exploration

# %%
df.shape
# Out:
# (185950, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# 0          1700.00  2019-12-30 00:01:00
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# ...

# %% [markdown]
# ### Data cleaning and Exploratory data analysis

# %%
df['Revenue'] = df['Price Each'] * df['Quantity Ordered']

print(df.head())
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#      Sales            City  Hour  Revenue
# 0  1700.00   New York City     0  1700.00
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Day'] = df['Order Date'].dt.day

print(df.head())
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12    11.95
#
# ...

# %% [markdown]
# ### Data Cleaning

# %%
df.drop(['Order ID', 'Order Date', 'Purchase Address'], axis = 1, inplace = True)

# %%
column=df.columns

# %%
df.drop(column[0], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                 Product  Quantity Ordered  Price Each  Month    Sales  \
# 0    Macbook Pro Laptop                 1     1700.00     12  1700.00
# 1    LG Washing Machine                 1      600.00     12   600.00
# 2  USB-C Charging Cable                 1       11.95     12    11.95
# 3      27in FHD Monitor                 1      149.99     12   149.99
# 4  USB-C Charging Cable                 1       11.95     12    11.95
#
#              City  Hour  Revenue  Year  Day
# 0   New York City     0  1700.00  2019   30
# 1   New York City     7   600.00  2019   29
# 2   New York City    18    11.95  2019   12
# 3   San Francisco    15   149.99  2019   22
# 4         Atlanta    12    11.95  2019   18

# %%
df.isna().sum()
# Out:
# Product             0
# Quantity Ordered    0
# Price Each          0
# Month               0
# Sales               0
# City                0
# Hour                0
# Revenue             0
# Year                0
# Day                 0
# dtype: int64

# %%
len(df)
# Out:
# 185950

# %%
df.columns
# Out:
# Index(['Product', 'Quantity Ordered', 'Price Each', 'Month', 'Sales', 'City',
#        'Hour', 'Revenue', 'Year', 'Day'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 22314

# %%
df=df.drop_duplicates()

# %%
df.head()
# Out:
#                 Product  Quantity Ordered  Price Each  Month    Sales  \
# 0    Macbook Pro Laptop                 1     1700.00     12  1700.00
# 1    LG Washing Machine                 1      600.00     12   600.00
# 2  USB-C Charging Cable                 1       11.95     12    11.95
# 3      27in FHD Monitor                 1      149.99     12   149.99
# 4  USB-C Charging Cable                 1       11.95     12    11.95
#
#              City  Hour  Revenue  Year  Day
# 0   New York City     0  1700.00  2019   30
# 1   New York City     7   600.00  2019   29
# 2   New York City    18    11.95  2019   12
# 3   San Francisco    15   149.99  2019   22
# 4         Atlanta    12    11.95  2019   18

# %%
len(df)
# Out:
# 163636

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize = (10,6))
sns.countplot(data = df, x = 'Month')
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
plt.figure(figsize=(12, 8))
df[numerical_columns].boxplot()
# Out:
# <Axes: >

# %%
plt.figure(figsize = (40,15))
sns.barplot(data = df, x = 'Product', y = 'Price Each')
# Out:
# <Axes: xlabel='Product', ylabel='Price Each'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

valid_rows = df[
    pd.to_numeric(df['Price Each'], errors='coerce').notna() & 
    pd.to_numeric(df['Quantity Ordered'], errors='coerce').notna()
]

# Convert columns to numeric
valid_rows['Price Each'] = pd.to_numeric(valid_rows['Price Each'])
valid_rows['Quantity Ordered'] = pd.to_numeric(valid_rows['Quantity Ordered'])

numeric_data = valid_rows.select_dtypes(include=['float64', 'int64'])

print("Numeric Data for Correlation:")
print(numeric_data.head())
# Out:
# Numeric Data for Correlation:
#    Quantity Ordered  Price Each    Sales  Hour  Revenue
# 0                 1     1700.00  1700.00     0  1700.00
# 1                 1      600.00   600.00     7   600.00
# 2                 1       11.95    11.95    18    11.95
# 3                 1      149.99   149.99    15   149.99
# 4                 1       11.95    11.95    12    11.95

# %%
correlation = df['Price Each'].corr(df['Quantity Ordered'])
print(f"Correlation between Price and Quantity: {correlation:.2f}")

correlation_matrix = numeric_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap (Filtered Data)')
plt.show()
# Out:
# Correlation between Price and Quantity: -0.16

# %%
df['Product'].value_counts()
# Out:
# Product
# AAA Batteries (4-pack)        18469
# AA Batteries (4-pack)         18123
# USB-C Charging Cable          18085
# Lightning Charging Cable      17806
# Wired Headphones              15962
# Apple Airpods Headphones      13293
# Bose SoundSport Headphones    11635
# 27in FHD Monitor               6885
# iPhone                         6345
# 27in 4K Gaming Monitor         5834
# 34in Ultrawide Monitor         5794
# Google Phone                   5170
# Flatscreen TV                  4580
# Macbook Pro Laptop             4463
# 20in Monitor                   3934
# ThinkPad Laptop                3930
# Vareebadd Phone                2026
# LG Washing Machine              661
# LG Dryer                        641
# Name: count, dtype: int64

# %%
df_encoded = pd.get_dummies(df, columns = ['Product'], drop_first = True)
df_encoded.head()
# Out:
#    Quantity Ordered  Price Each  Month    Sales            City  Hour  \
# 0                 1     1700.00     12  1700.00   New York City     0
# 1                 1      600.00     12   600.00   New York City     7
# 2                 1       11.95     12    11.95   New York City    18
# 3                 1      149.99     12   149.99   San Francisco    15
# 4                 1       11.95     12    11.95         Atlanta    12
#
#    Revenue  Year  Day  Product_27in 4K Gaming Monitor  ...  \
# 0  1700.00  2019   30                           False  ...
# 1   600.00  2019   29                           False  ...
# 2    11.95  2019   12                           False  ...
# 3   149.99  2019   22                           False  ...
# 4    11.95  2019   18                           False  ...
#
#    Product_Google Phone  Product_LG Dryer  Product_LG Washing Machine  \
# 0                 False             False                       False
# ...

# %%
df['City'].value_counts()
# Out:
# City
#  San Francisco    36102
#  Los Angeles      25465
#  New York City    21940
#  Boston           17968
#  Atlanta          13736
#  Dallas           13716
#  Seattle          13664
#  Portland         11653
#  Austin            9392
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df_encoded, columns = ['City'], drop_first = True)
df.head()
# Out:
#    Quantity Ordered  Price Each  Month    Sales  Hour  Revenue  Year  Day  \
# 0                 1     1700.00     12  1700.00     0  1700.00  2019   30
# 1                 1      600.00     12   600.00     7   600.00  2019   29
# 2                 1       11.95     12    11.95    18    11.95  2019   12
# 3                 1      149.99     12   149.99    15   149.99  2019   22
# 4                 1       11.95     12    11.95    12    11.95  2019   18
#
#    Product_27in 4K Gaming Monitor  Product_27in FHD Monitor  ...  \
# 0                           False                     False  ...
# 1                           False                     False  ...
# 2                           False                     False  ...
# 3                           False                      True  ...
# 4                           False                     False  ...
#
#    Product_Wired Headphones  Product_iPhone  City_ Austin  City_ Boston  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['Quantity Ordered', 'Price Each', 'Month', 'Sales', 'Hour']] = scaler.fit_transform(df[['Quantity Ordered', 'Price Each', 'Month', 'Sales', 'Hour']])
df.head()
# Out:
#    Quantity Ordered  Price Each     Month     Sales      Hour  Revenue  Year  \
# 0         -0.295858    4.401841  1.434453  4.395973 -2.589035  1700.00  2019
# 1         -0.295858    1.184350  1.434453  1.180155 -1.322471   600.00  2019
# 2         -0.295858   -0.535692  1.434453 -0.538993  0.667844    11.95  2019
# 3         -0.295858   -0.131926  1.434453 -0.135437  0.125031   149.99  2019
# 4         -0.295858   -0.535692  1.434453 -0.538993 -0.417782    11.95  2019
#
#    Day  Product_27in 4K Gaming Monitor  Product_27in FHD Monitor  ...  \
# 0   30                           False                     False  ...
# 1   29                           False                     False  ...
# 2   12                           False                     False  ...
# 3   22                           False                      True  ...
# 4   18                           False                     False  ...
#
#    Product_Wired Headphones  Product_iPhone  City_ Austin  City_ Boston  \
# ...

# %%
df=pd.read_csv(r"C:\Users\giree\Downloads\Sales Data.csv.zip")
df['Revenue'] = df['Price Each'] * df['Quantity Ordered']
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Day'] = df['Order Date'].dt.day

# %%
df['Month'] = df['Order Date'].dt.month

# Group by Month and calculate total revenue
monthly_sales = df.groupby('Month')['Revenue'].sum().sort_values(ascending=True)
print("Monthly Sales:\n", monthly_sales)

# Visualization
monthly_sales.plot(kind='bar', color='purple', figsize=(10, 5))
plt.title('Monthly Sales Performance')
plt.ylabel('Total Revenue')
plt.xlabel('Month')
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.show()
# Out:
# Monthly Sales:
#  Month
# 1     1822256.73
# 9     2097560.13
# 2     2202022.42
# 8     2244467.88
# 6     2577802.26
# 7     2647775.76
# 3     2807100.38
# 5     3152606.75
# 11    3199603.20
# 4     3390670.24
# 10    3736726.88
# 12    4613443.34
# Name: Revenue, dtype: float64

# %% [markdown]
# <b>Final Takeaways</b></br>
# 1.December is the best month for sales → run holiday promotions.</br>
# 2.Cheaper products sell more, expensive ones generate high revenue per unit.</br>
# 3.San Francisco, LA, and NYC are top-performing cities.</br>
# 4.Evenings are peak shopping time → target customers with offers at those hours.</br>
# 5.Discounts on mid/high-priced products can increase sales volume.</br>
# 6.Bundling accessories with premium products may increase total revenue</br>
#
# Insight: Confirms that sales volume + product pricing together drive revenue.
